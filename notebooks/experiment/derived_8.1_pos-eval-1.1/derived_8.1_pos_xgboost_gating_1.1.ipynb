# %% [markdown]
# # Section 1: Notebook Setup & Imports
#
# This section initializes the notebook environment, sets up path resolution to import project utilities, and imports necessary libraries for modeling, data handling, and evaluation. We also verify CUDA availability for GPU-accelerated XGBoost training.

# %%
import os
import sys
import random
from pathlib import Path
import time
import pickle
import math

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, r2_score, root_mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import torch
import xgboost as xgb
from xgboost import XGBRegressor

# Resolve project root path and append to sys.path
PROJECT_ROOT = os.path.abspath("../../../")
print(f"Project root: {PROJECT_ROOT}")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# Import metrics dashboard from project utilities
try:
    from u_dashboard.dashboard import metrics_dashboard
    print("Imported dashboard from u_dashboard.dashboard")
except ImportError as e:
    try:
        from Models.Utils.dashboard import metrics_dashboard
        print("Imported dashboard from Models.Utils")
    except ImportError as e2:
        from Utils.dashboard import metrics_dashboard
        print("Imported dashboard from local Utils")

import warnings
warnings.filterwarnings("ignore")

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
os.environ["PYTHONHASHSEED"] = str(SEED)
print(f"Random seed set to {SEED}")

# Setup plotting style
plt.style.use("default")
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True

# Verify CUDA/GPU availability for XGBoost
try:
    dummy = xgb.XGBRegressor(n_estimators=1, device="cuda")
    dummy.fit(np.array([[1.0]]), np.array([1.0]))
    XGB_DEVICE = "cuda"
    print("XGBoost CUDA support verified and enabled.")
except Exception as e:
    XGB_DEVICE = "cpu"
    print(f"XGBoost CUDA dummy test failed ({e}). Falling back to CPU.")

print("Environment setup complete.")
# Out:
# Project root: C:\Users\pan\Documents\GitHub\MDR-Project
# Imported dashboard from u_dashboard.dashboard
# Random seed set to 42
# XGBoost CUDA support verified and enabled.
# Environment setup complete.

# %% [markdown]
# # Section 2: Data Loading & Preprocessing
#
# This section loads the train, validation, and test splits for the `derived_8.1` dataset. We concatenate the train and validation sets to form the `trainval` split for model training, and import the regime thresholds ($T_1$, $T_2$) and the lists of selected features for overall and regime-specific modeling from `dataset_metadata.py`.

# %%
# Define path configurations
TRAIN_PATH = os.path.join(PROJECT_ROOT, "data/splits/derived_8.1_pos/train.csv")
VAL_PATH = os.path.join(PROJECT_ROOT, "data/splits/derived_8.1_pos/val.csv")
TEST_PATH = os.path.join(PROJECT_ROOT, "data/splits/derived_8.1_pos/test.csv")

# Load dataset splits
train_df = pd.read_csv(TRAIN_PATH)
val_df = pd.read_csv(VAL_PATH)
test_df = pd.read_csv(TEST_PATH)

print("Dataset splits loaded:")
print(f"  train: {train_df.shape}")
print(f"  val:   {val_df.shape}")
print(f"  test:  {test_df.shape}")

# Concatenate train and val for training+validation
trainval_df = pd.concat([train_df, val_df], axis=0).reset_index(drop=True)
print(f"  trainval (concatenated): {trainval_df.shape}")

# Import metadata and configuration constants from dataset_metadata.py using importlib
import importlib.util
metadata_path = os.path.join(PROJECT_ROOT, "data/splits/derived_8.1_pos/dataset_metadata.py")
spec = importlib.util.spec_from_file_location("dataset_metadata", metadata_path)
dataset_metadata = importlib.util.module_from_spec(spec)
spec.loader.exec_module(dataset_metadata)

T1 = dataset_metadata.T1
T2 = dataset_metadata.T2
DRY_THRESHOLD = dataset_metadata.DRY_THRESHOLD
WET_THRESHOLD = dataset_metadata.WET_THRESHOLD
OVERALL_SELECTED_FEATURES = dataset_metadata.OVERALL_SELECTED_FEATURES
DRY_SELECTED_FEATURES = dataset_metadata.DRY_SELECTED_FEATURES
TRANSITION_SELECTED_FEATURES = dataset_metadata.TRANSITION_SELECTED_FEATURES
WET_SELECTED_FEATURES = dataset_metadata.WET_SELECTED_FEATURES

# Import 2-Regime threshold and features
T_2REGIME = dataset_metadata.T_2REGIME
DRY_2REGIME_SELECTED_FEATURES = dataset_metadata.DRY_2REGIME_SELECTED_FEATURES
WET_2REGIME_SELECTED_FEATURES = dataset_metadata.WET_2REGIME_SELECTED_FEATURES

TARGET_COL = "soil_moisture_5cm"

print("\nThresholds and Selected Features loaded successfully:")
print(f"  Regime Thresholds: T1={T1}, T2={T2}")
print(f"  Overall Selected Features:    {len(OVERALL_SELECTED_FEATURES)}")
print(f"  Dry Selected Features:        {len(DRY_SELECTED_FEATURES)}")
print(f"  Transition Selected Features: {len(TRANSITION_SELECTED_FEATURES)}")
print(f"  Wet Selected Features:        {len(WET_SELECTED_FEATURES)}")
print(f"  2-Regime Threshold: T_2REGIME={T_2REGIME}")
print(f"  2-Regime Dry Selected Features: {len(DRY_2REGIME_SELECTED_FEATURES)}")
print(f"  2-Regime Wet Selected Features: {len(WET_2REGIME_SELECTED_FEATURES)}")

# Compute temporal recency weights (Drift)
years_tv = trainval_df["year"].astype(float)
max_year = years_tv.max()
beta = 0.2
w_trainval = np.exp(beta * (years_tv - max_year))
w_trainval = w_trainval / w_trainval.mean()

print(f"\nTemporal Recency Weighting (Drift) initialized with beta={beta}:")
print(f"  Min weight: {w_trainval.min():.4f}")
print(f"  Max weight: {w_trainval.max():.4f}")
# Out:
# Dataset splits loaded:
#   train: (15964, 499)
#   val:   (7149, 499)
#   test:  (8902, 499)
#   trainval (concatenated): (23113, 499)
#
# Thresholds and Selected Features loaded successfully:
#   Regime Thresholds: T1=0.159, T2=0.248
#   Overall Selected Features:    40
#   Dry Selected Features:        40
#   Transition Selected Features: 40
#   Wet Selected Features:        40
#   2-Regime Threshold: T_2REGIME=0.159
#   2-Regime Dry Selected Features: 40
#   2-Regime Wet Selected Features: 40
#
# Temporal Recency Weighting (Drift) initialized with beta=0.2:
#   Min weight: 0.5828
#   Max weight: 1.5843

# %% [markdown]
# # Section 3: Model 1 - No Gating (Single Global Model)
#
# This section trains a single global XGBoost model on the concatenated `trainval` split using the `OVERALL_SELECTED_FEATURES`. We evaluate the model's performance on the test set using the default evaluation metrics (R?, MAE, and bias).

# %%
# Define global model parameters matching v25 / v19.3 configuration
XGB_PARAMS_GLOBAL = dict(
    objective="reg:absoluteerror",
    random_state=SEED,
    n_jobs=-1,
    subsample=0.9,
    colsample_bytree=0.8,
    max_depth=8,
    min_child_weight=2,
    n_estimators=5500,
    learning_rate=0.04,
    reg_lambda=1.5,
    reg_alpha=0.03,
    gamma=0.0,
    device=XGB_DEVICE
)

print("XGBoost Global Model Parameters initialized:")
print(f"  device: {XGB_PARAMS_GLOBAL['device']}")

# Train global model
print("\nTraining XGBoost Global Model...")
start_time = time.time()
xgb_global = XGBRegressor(**XGB_PARAMS_GLOBAL)
xgb_global.fit(
    trainval_df[OVERALL_SELECTED_FEATURES],
    trainval_df[TARGET_COL],
    sample_weight=w_trainval,
    verbose=0
)
print(f"Training completed in {time.time() - start_time:.2f} seconds.")

# Predict on the test split
y_test = np.asarray(test_df[TARGET_COL]).ravel()
pred_global = np.asarray(xgb_global.predict(test_df[OVERALL_SELECTED_FEATURES])).ravel()

# Display performance metrics using the project dashboard
metrics_dashboard(
    y_test,
    pred_global,
    name="Model 1 | Single Global XGBoost Model (No Gating)"
)

# Extract and print individual temporal performance metrics
metrics_global_dict = metrics_dashboard(y_test, pred_global, show=False, return_dict=True)
print("\n===== GLOBAL MODEL METRICS =====")
print(f"R2 Score:  {metrics_global_dict['r2']:.5f}")
print(f"MAE:       {metrics_global_dict['mae']:.5f}")
print(f"Bias:      {metrics_global_dict['bias']:.5f}")
# Out:
# XGBoost Global Model Parameters initialized:
#   device: cuda
#
# Training XGBoost Global Model...
# Training completed in 32.45 seconds.
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Model 1 | Single Global XGBoost Model (No Gating) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 8,902</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">0.4901</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0752</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0743</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0113</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.490</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 49.00942579745205%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#eab308; font-weight: bold;">0.710</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 71.04679192549708%; height: 100%; background: #eab308; box-shadow: 0 0 8px #eab30866;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.989</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.87180077884605%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.150 &nbsp; -0.047 &nbsp; -0.001 &nbsp; +0.036 &nbsp; +0.096</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0404</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.05538</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.04040</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.07434</span></div>
#         </div>
#     </div>
# ===== GLOBAL MODEL METRICS =====
# R2 Score:  0.49009
# MAE:       0.05538
# Bias:      -0.01128

# %%
# Compute residuals for Model 1
residuals_global = y_test - pred_global

# Create "Residuals vs True SM | Global Model (No Gating)" scatter plot
plt.figure(figsize=(7, 5))
plt.scatter(y_test, residuals_global, s=8, alpha=0.5, color='#2a9d8f')
plt.axhline(0, color='black', linestyle='--', linewidth=1.2, alpha=0.8)
plt.xlabel("True Soil Moisture")
plt.ylabel("Residual (true - pred)")
plt.title("Residuals vs True SM | Global Model (No Gating)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Section 4: Model 2 - Regime Specialists (Oracle Hard Gating)
#
# In this section, we implement **Oracle Hard Gating**. We split the combined training and validation dataset (`trainval_df`) into three disjoint subsets based on the true target soil moisture (`soil_moisture_5cm`) using the valley-calibrated thresholds $T_1 = 0.16$ and $T_2 = 0.25$:
# - **Dry Regime**: $\text{SM} < 0.16$
# - **Transition Regime**: $0.16 \le \text{SM} < 0.25$
# - **Wet Regime**: $\text{SM} \ge 0.25$
#
# Three specialist models (`xgb_dry`, `xgb_transition`, `xgb_wet`) are trained on their respective subsets using their respective optimized features (`DRY_SELECTED_FEATURES`, `TRANSITION_SELECTED_FEATURES`, `WET_SELECTED_FEATURES`). We then evaluate each specialist model on its corresponding slice of the test set.

# %%
# Define parameter dictionaries for each regime specialist
XGB_PARAMS_DRY = dict(
    objective="reg:absoluteerror",
    random_state=SEED,
    n_jobs=-1,
    subsample=0.9,
    colsample_bytree=0.8,
    max_depth=8,
    min_child_weight=2,
    n_estimators=5500,
    learning_rate=0.04,
    reg_lambda=1.5,
    reg_alpha=0.03,
    gamma=0.0,
    device=XGB_DEVICE
)

XGB_PARAMS_TRANSITION = dict(
    objective="reg:absoluteerror",
    random_state=SEED,
    n_jobs=-1,
    max_depth=7,
    min_child_weight=5,
    subsample=0.9,
    colsample_bytree=0.85,
    n_estimators=8000,
    learning_rate=0.03,
    reg_lambda=3.0,
    reg_alpha=0.05,
    device=XGB_DEVICE
)

XGB_PARAMS_WET = dict(
    objective="reg:squarederror",
    random_state=SEED,
    n_jobs=-1,
    max_depth=10,
    min_child_weight=1,
    subsample=1.0,
    colsample_bytree=0.9,
    n_estimators=6000,
    learning_rate=0.03,
    reg_lambda=0.3,
    reg_alpha=0.0,
    device=XGB_DEVICE
)

print("XGBoost Specialist Parameters initialized.")

# Generate regime masks for trainval
y_trainval = np.asarray(trainval_df[TARGET_COL]).ravel()
mask_dry_tv = y_trainval < T1
mask_transition_tv = (y_trainval >= T1) & (y_trainval < T2)
mask_wet_tv = y_trainval >= T2

print("\nTrainval Split Regime Distribution:")
print(f"  Dry:        {mask_dry_tv.sum():,}")
print(f"  Transition: {mask_transition_tv.sum():,}")
print(f"  Wet:        {mask_wet_tv.sum():,}")

# 1. Train Dry Specialist
print("\nTraining Dry Specialist model...")
start_time = time.time()
xgb_dry = XGBRegressor(**XGB_PARAMS_DRY)
xgb_dry.fit(
    trainval_df.loc[mask_dry_tv, DRY_SELECTED_FEATURES],
    trainval_df.loc[mask_dry_tv, TARGET_COL],
    sample_weight=w_trainval[mask_dry_tv],
    verbose=0
)
print(f"Dry Specialist training completed in {time.time() - start_time:.2f} seconds.")

# 2. Train Transition Specialist
print("Training Transition Specialist model...")
start_time = time.time()
xgb_transition = XGBRegressor(**XGB_PARAMS_TRANSITION)
xgb_transition.fit(
    trainval_df.loc[mask_transition_tv, TRANSITION_SELECTED_FEATURES],
    trainval_df.loc[mask_transition_tv, TARGET_COL],
    sample_weight=w_trainval[mask_transition_tv],
    verbose=0
)
print(f"Transition Specialist training completed in {time.time() - start_time:.2f} seconds.")

# 3. Train Wet Specialist
print("Training Wet Specialist model...")
start_time = time.time()
xgb_wet = XGBRegressor(**XGB_PARAMS_WET)
xgb_wet.fit(
    trainval_df.loc[mask_wet_tv, WET_SELECTED_FEATURES],
    trainval_df.loc[mask_wet_tv, TARGET_COL],
    sample_weight=w_trainval[mask_wet_tv],
    verbose=0
)
print(f"Wet Specialist training completed in {time.time() - start_time:.2f} seconds.")
print("All specialist models successfully trained.")
# Out:
# XGBoost Specialist Parameters initialized.
#
# Trainval Split Regime Distribution:
#   Dry:        8,432
#   Transition: 5,264
#   Wet:        9,417
#
# Training Dry Specialist model...
# Dry Specialist training completed in 29.19 seconds.
# Training Transition Specialist model...
# Transition Specialist training completed in 33.12 seconds.
# Training Wet Specialist model...
# Wet Specialist training completed in 12.32 seconds.
# All specialist models successfully trained.

# %%
# Generate regime masks for the test set (Oracle Gating)
mask_dry_test = y_test < T1
mask_transition_test = (y_test >= T1) & (y_test < T2)
mask_wet_test = y_test >= T2

print("Test Split Regime Distribution:")
print(f"  Dry:        {mask_dry_test.sum():,}")
print(f"  Transition: {mask_transition_test.sum():,}")
print(f"  Wet:        {mask_wet_test.sum():,}")

# Predict on the full test dataset using each specialist
pred_dry_test = np.asarray(xgb_dry.predict(test_df[DRY_SELECTED_FEATURES])).ravel()
pred_transition_test = np.asarray(xgb_transition.predict(test_df[TRANSITION_SELECTED_FEATURES])).ravel()
pred_wet_test = np.asarray(xgb_wet.predict(test_df[WET_SELECTED_FEATURES])).ravel()

# Evaluate each specialist on its respective test regime slice
print("\n===== REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====")

# Dry Specialist on Dry Test Slice
print("\n--- 1. Dry Specialist (Evaluating on SM < T1) ---")
metrics_dashboard(
    y_test[mask_dry_test],
    pred_dry_test[mask_dry_test],
    name="Dry Specialist Model (Dry Slice)"
)

# Transition Specialist on Transition Test Slice
print("\n--- 2. Transition Specialist (Evaluating on T1 <= SM < T2) ---")
metrics_dashboard(
    y_test[mask_transition_test],
    pred_transition_test[mask_transition_test],
    name="Transition Specialist Model (Transition Slice)"
)

# Wet Specialist on Wet Test Slice
print("\n--- 3. Wet Specialist (Evaluating on SM >= T2) ---")
metrics_dashboard(
    y_test[mask_wet_test],
    pred_wet_test[mask_wet_test],
    name="Wet Specialist Model (Wet Slice)"
)
# Out:
# Test Split Regime Distribution:
#   Dry:        3,333
#   Transition: 2,441
#   Wet:        3,128
# ===== REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====
#
# --- 1. Dry Specialist (Evaluating on SM < T1) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Dry Specialist Model (Dry Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 3,333</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">0.0198</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0455</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0419</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0176</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.020</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 1.9794841642662764%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.448</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 44.80641959240608%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.982</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.24422562454436%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.091 &nbsp; -0.042 &nbsp; -0.015 &nbsp; +0.009 &nbsp; +0.049</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0279</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03535</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02791</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.04194</span></div>
#         </div>
#     </div>
# --- 2. Transition Specialist (Evaluating on T1 <= SM < T2) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Transition Specialist Model (Transition Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 2,441</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">-0.0155</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0258</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0258</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">+0.0001</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">-0.016</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 0%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.228</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 22.81330391765603%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">1.000</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 99.99164423340416%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.043 &nbsp; -0.020 &nbsp; +0.001 &nbsp; +0.020 &nbsp; +0.040</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0200</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.02170</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02005</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.02582</span></div>
#         </div>
#     </div>
# --- 3. Wet Specialist (Evaluating on SM >= T2) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Wet Specialist Model (Wet Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 3,128</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">-0.2562</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0391</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0376</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0106</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">-0.256</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 0%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.269</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 26.855466836549446%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.989</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.94209354592253%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.073 &nbsp; -0.037 &nbsp; -0.008 &nbsp; +0.014 &nbsp; +0.051</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0265</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03126</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02653</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.03761</span></div>
#         </div>
#     </div>

# %% [markdown]
# # Section 5: Model 3 - Combined Oracle Performance & Residuals Plot
#
# In this final section, we evaluate the **Combined Oracle Hard Gated Model**. For each sample in the test set, we route the prediction to the corresponding regime specialist based on the *true* target soil moisture of that sample:
# - If $y_{true} < 0.16$, we select the Dry specialist prediction.
# - If $0.16 \le y_{true} < 0.25$, we select the Transition specialist prediction.
# - If $y_{true} \ge 0.25$, we select the Wet specialist prediction.
#
# We evaluate this combined prediction set against the test labels and generate the "Residuals vs True SM | Hard Gated (Oracle)" diagnostic plot.

# %%
# Route predictions using oracle routing masks
pred_combined = np.zeros_like(y_test, dtype=float)
pred_combined[mask_dry_test] = pred_dry_test[mask_dry_test]
pred_combined[mask_transition_test] = pred_transition_test[mask_transition_test]
pred_combined[mask_wet_test] = pred_wet_test[mask_wet_test]

# Evaluate the combined oracle performance
metrics_dashboard(
    y_test,
    pred_combined,
    name="Model 3 | Combined Oracle Hard Gated Model (MoE)"
)

metrics_combined_dict = metrics_dashboard(y_test, pred_combined, show=False, return_dict=True)
print("\n===== COMBINED ORACLE MODEL METRICS =====")
print(f"R? Score:  {metrics_combined_dict['r2']:.5f}")
print(f"MAE:       {metrics_combined_dict['mae']:.5f}")
print(f"Bias:      {metrics_combined_dict['bias']:.5f}")
# Out:
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Model 3 | Combined Oracle Hard Gated Model (MoE) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 8,902</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">0.8653</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0386</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0373</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0103</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.865</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 86.53477742767006%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.935</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 93.53448426489493%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.990</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.97318232358037%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.078 &nbsp; -0.033 &nbsp; -0.008 &nbsp; +0.016 &nbsp; +0.045</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0250</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03017</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02503</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.03725</span></div>
#         </div>
#     </div>
# ===== COMBINED ORACLE MODEL METRICS =====
# R? Score:  0.86535
# MAE:       0.03017
# Bias:      -0.01027

# %%
# Compute residuals
residuals = y_test - pred_combined

# Create "Residuals vs True SM | Hard Gated (Oracle)" scatter plot
plt.figure(figsize=(7, 5))
plt.scatter(y_test, residuals, s=8, alpha=0.5, color='#4f82c8')
plt.axhline(0, color='black', linestyle='--', linewidth=1.2, alpha=0.8)
plt.xlabel("True Soil Moisture")
plt.ylabel("Residual (true - pred)")
plt.title("Residuals vs True SM | Hard Gated (Oracle)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Section 6: Model 4 - Regime Specialists using Overall Features
#
# In this section, we implement a **Regime Specialist Model using Overall Selected Features**. This model is trained using the same regime-specific thresholds ($T_1 = 0.16$ and $T_2 = 0.25$) to split the training set, but all three specialist models (`xgb_dry_overall`, `xgb_transition_overall`, `xgb_wet_overall`) are trained using the same `OVERALL_SELECTED_FEATURES` instead of the regime-specific selected features. This serves as an ablation study to understand the impact of regime-specific feature selection.

# %%
# Train Dry Specialist using overall features
print("\nTraining Dry Specialist model (Overall Features)...")
start_time = time.time()
xgb_dry_overall = XGBRegressor(**XGB_PARAMS_DRY)
xgb_dry_overall.fit(
    trainval_df.loc[mask_dry_tv, OVERALL_SELECTED_FEATURES],
    trainval_df.loc[mask_dry_tv, TARGET_COL],
    sample_weight=w_trainval[mask_dry_tv],
    verbose=0
)
print(f"Dry Specialist (Overall Features) training completed in {time.time() - start_time:.2f} seconds.")

# Train Transition Specialist using overall features
print("Training Transition Specialist model (Overall Features)...")
start_time = time.time()
xgb_transition_overall = XGBRegressor(**XGB_PARAMS_TRANSITION)
xgb_transition_overall.fit(
    trainval_df.loc[mask_transition_tv, OVERALL_SELECTED_FEATURES],
    trainval_df.loc[mask_transition_tv, TARGET_COL],
    sample_weight=w_trainval[mask_transition_tv],
    verbose=0
)
print(f"Transition Specialist (Overall Features) training completed in {time.time() - start_time:.2f} seconds.")

# Train Wet Specialist using overall features
print("Training Wet Specialist model (Overall Features)...")
start_time = time.time()
xgb_wet_overall = XGBRegressor(**XGB_PARAMS_WET)
xgb_wet_overall.fit(
    trainval_df.loc[mask_wet_tv, OVERALL_SELECTED_FEATURES],
    trainval_df.loc[mask_wet_tv, TARGET_COL],
    sample_weight=w_trainval[mask_wet_tv],
    verbose=0
)
print(f"Wet Specialist (Overall Features) training completed in {time.time() - start_time:.2f} seconds.")
print("All overall-feature specialist models successfully trained.")
# Out:
# Training Dry Specialist model (Overall Features)...
# Dry Specialist (Overall Features) training completed in 30.25 seconds.
# Training Transition Specialist model (Overall Features)...
# Transition Specialist (Overall Features) training completed in 33.41 seconds.
# Training Wet Specialist model (Overall Features)...
# Wet Specialist (Overall Features) training completed in 12.90 seconds.
# All overall-feature specialist models successfully trained.

# %%
# Predict on the full test dataset using each overall-feature specialist
pred_dry_overall_test = np.asarray(xgb_dry_overall.predict(test_df[OVERALL_SELECTED_FEATURES])).ravel()
pred_transition_overall_test = np.asarray(xgb_transition_overall.predict(test_df[OVERALL_SELECTED_FEATURES])).ravel()
pred_wet_overall_test = np.asarray(xgb_wet_overall.predict(test_df[OVERALL_SELECTED_FEATURES])).ravel()

# Evaluate each specialist on its respective test regime slice
print("\n===== OVERALL-FEATURE REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====")

# Dry Specialist on Dry Test Slice
print("\n--- 1. Dry Specialist (Overall Features) (Evaluating on SM < T1) ---")
metrics_dashboard(
    y_test[mask_dry_test],
    pred_dry_overall_test[mask_dry_test],
    name="Dry Specialist (Overall Features) (Dry Slice)"
)

# Transition Specialist on Transition Test Slice
print("\n--- 2. Transition Specialist (Overall Features) (Evaluating on T1 <= SM < T2) ---")
metrics_dashboard(
    y_test[mask_transition_test],
    pred_transition_overall_test[mask_transition_test],
    name="Transition Specialist (Overall Features) (Transition Slice)"
)

# Wet Specialist on Wet Test Slice
print("\n--- 3. Wet Specialist (Overall Features) (Evaluating on SM >= T2) ---")
metrics_dashboard(
    y_test[mask_wet_test],
    pred_wet_overall_test[mask_wet_test],
    name="Wet Specialist (Overall Features) (Wet Slice)"
)
# Out:
# ===== OVERALL-FEATURE REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====
#
# --- 1. Dry Specialist (Overall Features) (Evaluating on SM < T1) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Dry Specialist (Overall Features) (Dry Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 3,333</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">0.0873</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0439</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0399</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0182</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.087</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 8.726612452356674%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.507</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 50.684026022004694%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.982</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.18376368082504%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.091 &nbsp; -0.044 &nbsp; -0.016 &nbsp; +0.009 &nbsp; +0.045</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0283</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03449</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02825</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.03994</span></div>
#         </div>
#     </div>
# --- 2. Transition Specialist (Overall Features) (Evaluating on T1 <= SM < T2) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Transition Specialist (Overall Features) (Transition Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 2,441</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">-0.0634</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0264</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0264</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">+0.0004</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">-0.063</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 0%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.200</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 19.993389812476078%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">1.000</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 99.9557448356721%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.045 &nbsp; -0.020 &nbsp; +0.002 &nbsp; +0.021 &nbsp; +0.041</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0208</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.02234</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02083</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.02642</span></div>
#         </div>
#     </div>
# --- 3. Wet Specialist (Overall Features) (Evaluating on SM >= T2) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Wet Specialist (Overall Features) (Wet Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 3,128</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">-0.2066</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0383</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0371</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0096</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">-0.207</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 0%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.306</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 30.593206170924418%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.990</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 99.04467413712035%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.070 &nbsp; -0.036 &nbsp; -0.009 &nbsp; +0.016 &nbsp; +0.051</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0268</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03100</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02680</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.03708</span></div>
#         </div>
#     </div>

# %% [markdown]
# # Section 7: Model 5 - Combined Oracle Performance & Residuals (Overall Features)
#
# In this section, we evaluate the **Combined Oracle Gated Model with Overall Selected Features**. We route test predictions based on the true regime gating just like Model 3, but using the specialists trained on overall features. We then evaluate this combined prediction set against the test labels and generate the "Residuals vs True SM | Hard Gated (Oracle - Overall Features)" diagnostic plot.

# %%
# Route predictions using oracle routing masks for overall-feature models
pred_combined_overall = np.zeros_like(y_test, dtype=float)
pred_combined_overall[mask_dry_test] = pred_dry_overall_test[mask_dry_test]
pred_combined_overall[mask_transition_test] = pred_transition_overall_test[mask_transition_test]
pred_combined_overall[mask_wet_test] = pred_wet_overall_test[mask_wet_test]

# Evaluate the combined oracle performance
metrics_dashboard(
    y_test,
    pred_combined_overall,
    name="Model 5 | Combined Oracle Hard Gated Model (Overall Features)"
)

metrics_combined_overall_dict = metrics_dashboard(y_test, pred_combined_overall, show=False, return_dict=True)
print("\n===== COMBINED ORACLE MODEL (OVERALL FEATURES) METRICS =====")
print(f"R2 Score:  {metrics_combined_overall_dict['r2']:.5f}")
print(f"MAE:       {metrics_combined_overall_dict['mae']:.5f}")
print(f"Bias:      {metrics_combined_overall_dict['bias']:.5f}")
# Out:
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Model 5 | Combined Oracle Hard Gated Model (Overall Features) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 8,902</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">0.8713</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0378</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0364</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0100</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.871</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 87.12842727287742%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.938</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 93.8363723521732%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.990</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.99643359977833%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.074 &nbsp; -0.034 &nbsp; -0.008 &nbsp; +0.016 &nbsp; +0.045</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0249</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.02993</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02487</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.03642</span></div>
#         </div>
#     </div>
# ===== COMBINED ORACLE MODEL (OVERALL FEATURES) METRICS =====
# R2 Score:  0.87128
# MAE:       0.02993
# Bias:      -0.01004

# %%
# Compute residuals for overall-features model
residuals_overall = y_test - pred_combined_overall

# Create "Residuals vs True SM | Hard Gated (Oracle - Overall Features)" scatter plot
plt.figure(figsize=(7, 5))
plt.scatter(y_test, residuals_overall, s=8, alpha=0.5, color='#9b5de5')
plt.axhline(0, color='black', linestyle='--', linewidth=1.2, alpha=0.8)
plt.xlabel("True Soil Moisture")
plt.ylabel("Residual (true - pred)")
plt.title("Residuals vs True SM | Hard Gated (Oracle - Overall Features)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Section 8: Model 6 - 2-Regime Specialists (Oracle Hard Gating)
#
# In this section, we implement **2-Regime Oracle Hard Gating** as a potential alternative to the 3-regime model. We partition the combined training and validation dataset (	rainval_df) into two disjoint subsets using the valley-calibrated threshold  = 0.16$ (exact valley at .159$):
# - **Dry Regime**: $\text{SM} < 0.16$
# - **Wet Regime**: $\text{SM} \ge 0.16$
#
# Two specialist models (xgb_dry_2r and xgb_wet_2r) are trained on their respective subsets using their respective optimized features (DRY_2REGIME_SELECTED_FEATURES and WET_2REGIME_SELECTED_FEATURES). We then evaluate each specialist model on its corresponding slice of the test set, route test predictions using oracle gating, and evaluate the overall combined performance.

# %%
# Define parameters for the 2-regime specialists (reusing parameters matching the dry and wet specialists)
XGB_PARAMS_DRY_2R = dict(
    objective="reg:absoluteerror",
    random_state=SEED,
    n_jobs=-1,
    subsample=0.9,
    colsample_bytree=0.8,
    max_depth=8,
    min_child_weight=2,
    n_estimators=5500,
    learning_rate=0.04,
    reg_lambda=1.5,
    reg_alpha=0.03,
    gamma=0.0,
    device=XGB_DEVICE
)

XGB_PARAMS_WET_2R = dict(
    objective="reg:squarederror",
    random_state=SEED,
    n_jobs=-1,
    max_depth=10,
    min_child_weight=1,
    subsample=1.0,
    colsample_bytree=0.9,
    n_estimators=6000,
    learning_rate=0.03,
    reg_lambda=0.3,
    reg_alpha=0.0,
    device=XGB_DEVICE
)

# Generate regime masks for trainval
mask_dry_tv_2r = y_trainval < T_2REGIME
mask_wet_tv_2r = y_trainval >= T_2REGIME

print("Trainval Split 2-Regime Distribution:")
print(f"  Dry Regime: {mask_dry_tv_2r.sum():,}")
print(f"  Wet Regime: {mask_wet_tv_2r.sum():,}")

# 1. Train Dry Specialist (2R)
print("\nTraining Dry Specialist (2-Regime) model...")
start_time = time.time()
xgb_dry_2r = XGBRegressor(**XGB_PARAMS_DRY_2R)
xgb_dry_2r.fit(
    trainval_df.loc[mask_dry_tv_2r, DRY_2REGIME_SELECTED_FEATURES],
    trainval_df.loc[mask_dry_tv_2r, TARGET_COL],
    sample_weight=w_trainval[mask_dry_tv_2r],
    verbose=0
)
print(f"Dry Specialist (2-Regime) training completed in {time.time() - start_time:.2f} seconds.")

# 2. Train Wet Specialist (2R)
print("Training Wet Specialist (2-Regime) model...")
start_time = time.time()
xgb_wet_2r = XGBRegressor(**XGB_PARAMS_WET_2R)
xgb_wet_2r.fit(
    trainval_df.loc[mask_wet_tv_2r, WET_2REGIME_SELECTED_FEATURES],
    trainval_df.loc[mask_wet_tv_2r, TARGET_COL],
    sample_weight=w_trainval[mask_wet_tv_2r],
    verbose=0
)
print(f"Wet Specialist (2-Regime) training completed in {time.time() - start_time:.2f} seconds.")
print("2-Regime specialist models successfully trained.")

# Generate regime masks for the test set
mask_dry_test_2r = y_test < T_2REGIME
mask_wet_test_2r = y_test >= T_2REGIME

print("\nTest Split 2-Regime Distribution:")
print(f"  Dry Regime: {mask_dry_test_2r.sum():,}")
print(f"  Wet Regime: {mask_wet_test_2r.sum():,}")

# Predict on the full test dataset using each specialist
pred_dry_test_2r = np.asarray(xgb_dry_2r.predict(test_df[DRY_2REGIME_SELECTED_FEATURES])).ravel()
pred_wet_test_2r = np.asarray(xgb_wet_2r.predict(test_df[WET_2REGIME_SELECTED_FEATURES])).ravel()

# Evaluate each specialist on its respective test regime slice
print("\n===== 2-REGIME REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====")

# Dry Specialist on Dry Test Slice
print("\n--- 1. Dry Specialist (Evaluating on SM < T_2REGIME) ---")
metrics_dashboard(
    y_test[mask_dry_test_2r],
    pred_dry_test_2r[mask_dry_test_2r],
    name="Dry Specialist Model (2R - Dry Slice)"
)

# Wet Specialist on Wet Test Slice
print("\n--- 2. Wet Specialist (Evaluating on SM >= T_2REGIME) ---")
metrics_dashboard(
    y_test[mask_wet_test_2r],
    pred_wet_test_2r[mask_wet_test_2r],
    name="Wet Specialist Model (2R - Wet Slice)"
)

# Route predictions using oracle routing masks for 2-regime model
pred_combined_2r = np.zeros_like(y_test, dtype=float)
pred_combined_2r[mask_dry_test_2r] = pred_dry_test_2r[mask_dry_test_2r]
pred_combined_2r[mask_wet_test_2r] = pred_wet_test_2r[mask_wet_test_2r]

# Evaluate the combined oracle performance for 2-regime model
metrics_dashboard(
    y_test,
    pred_combined_2r,
    name="Model 6 | Combined Oracle Hard Gated Model (2-Regime)"
)

metrics_combined_2r_dict = metrics_dashboard(y_test, pred_combined_2r, show=False, return_dict=True)
print("\n===== COMBINED 2-REGIME ORACLE MODEL METRICS =====")
print(f"R2 Score:  {metrics_combined_2r_dict['r2']:.5f}")
print(f"MAE:       {metrics_combined_2r_dict['mae']:.5f}")
print(f"Bias:      {metrics_combined_2r_dict['bias']:.5f}")
# Out:
# Trainval Split 2-Regime Distribution:
#   Dry Regime: 8,432
#   Wet Regime: 14,681
#
# Training Dry Specialist (2-Regime) model...
# Dry Specialist (2-Regime) training completed in 29.89 seconds.
# Training Wet Specialist (2-Regime) model...
# Wet Specialist (2-Regime) training completed in 16.42 seconds.
# 2-Regime specialist models successfully trained.
#
# Test Split 2-Regime Distribution:
#   Dry Regime: 3,333
#   Wet Regime: 5,569
# ===== 2-REGIME REGIME SPECIALIST PERFORMANCE (ON TARGET SLICES) =====
#
# --- 1. Dry Specialist (Evaluating on SM < T_2REGIME) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Dry Specialist Model (2R - Dry Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 3,333</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">0.0198</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0455</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0419</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0176</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.020</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 1.9794841642662764%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.448</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 44.80641959240608%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.982</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.24422562454436%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.091 &nbsp; -0.042 &nbsp; -0.015 &nbsp; +0.009 &nbsp; +0.049</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0279</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.03535</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.02791</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.04194</span></div>
#         </div>
#     </div>
# --- 2. Wet Specialist (Evaluating on SM >= T_2REGIME) ---
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Wet Specialist Model (2R - Wet Slice) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 5,569</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #ef4444">-0.0471</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0574</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0568</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0085</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#ef4444; font-weight: bold;">-0.047</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 0%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#ef4444; font-weight: bold;">0.380</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 38.01911776699077%; height: 100%; background: #ef4444; box-shadow: 0 0 8px #ef444466;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.991</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 99.14765285752281%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.110 &nbsp; -0.043 &nbsp; -0.007 &nbsp; +0.027 &nbsp; +0.082</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0357</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.04452</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.03568</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.05677</span></div>
#         </div>
#     </div>
#     <div style="background: linear-gradient(145deg, #1e293b, #0f172a); border: 1px solid rgba(255, 255, 255, 0.1); border-radius: 16px; padding: 24px; color: #f8fafc; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, Helvetica;">
#         <div style="display: flex; justify-content: space-between; align-items: baseline; margin-bottom: 20px; border-bottom: 1px solid rgba(255, 255, 255, 0.1); padding-bottom: 12px;">
#             <div style="font-size: 20px; font-weight: 800; letter-spacing: -0.5px;">Model 6 | Combined Oracle Hard Gated Model (2-Regime) <span style="font-size: 12px; font-weight: 400; color: #94a3b8; margin-left: 8px;"></span></div>
#             <div style="font-family: monospace; color: #94a3b8; font-size: 12px;">N = 8,902</div>
#         </div>
#
#         <div style="display: grid; grid-template-columns: repeat(4, 1fr); gap: 15px;">
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">R-Squared</div><div style="font-size: 24px; font-weight: 900; color: #eab308">0.7443</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">RMSE</div><div style="font-size: 24px; font-weight: 900;">0.0532</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">ubRMSE</div><div style="font-size: 24px; font-weight: 900;">0.0519</div></div>
#             <div><div style="color: #94a3b8; font-size: 10px; font-weight: 700; text-transform: uppercase;">Bias</div><div style="font-size: 24px; font-weight: 900; color: #22c55e">-0.0119</div></div>
#         </div>
#
#         <div style="margin-top: 25px; display: flex; flex-wrap: wrap; gap: 20px; background: rgba(15, 23, 42, 0.4); padding: 15px; border-radius: 12px;">
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">R² Accuracy</span>
#                 <span style="color:#eab308; font-weight: bold;">0.744</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 74.43120805771792%; height: 100%; background: #eab308; box-shadow: 0 0 8px #eab30866;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Pearson Corr</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.871</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 87.08203995364782%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#
#         <div style="flex: 1; min-width: 180px; margin-bottom: 8px;">
#             <div style="display: flex; justify-content: space-between; font-family: monospace; font-size: 11px; margin-bottom: 4px;">
#                 <span style="color:#94a3b8">Residual Bias</span>
#                 <span style="color:#22c55e; font-weight: bold;">0.988</span>
#             </div>
#             <div style="height: 4px; background: rgba(255,255,255,0.1); border-radius: 2px; overflow: hidden;">
#                 <div style="width: 98.80940044598415%; height: 100%; background: #22c55e; box-shadow: 0 0 8px #22c55e66;"></div>
#             </div>
#         </div>
#
#         </div>
#
#
#         <div style="margin-top: 15px; padding: 10px 5px; font-size: 11px; font-family: ui-monospace, monospace; border-top: 1px solid rgba(255, 255, 255, 0.1);">
#             <span style="color: #94a3b8; font-weight: bold;">ERR QUANTILES [5/25/50/75/95]:</span>
#             <span style="color: #60a5fa; margin-left: 8px;">-0.100 &nbsp; -0.043 &nbsp; -0.010 &nbsp; +0.021 &nbsp; +0.073</span>
#             <span style="margin-left: 20px; color: #94a3b8;">REF (MED|ERR|): 0.0321</span>
#         </div>
#
#
#         <div style="margin-top: 10px; display: grid; grid-template-columns: repeat(3, 1fr); font-size: 11px; font-family: monospace; color: #94a3b8; opacity: 0.8;">
#             <div>MAE: <span style="color: #f8fafc">0.04108</span></div>
#             <div>MED |ERR|: <span style="color: #f8fafc">0.03210</span></div>
#             <div>STD(ERR): <span style="color: #f8fafc">0.05190</span></div>
#         </div>
#     </div>
# ===== COMBINED 2-REGIME ORACLE MODEL METRICS =====
# R2 Score:  0.74431
# MAE:       0.04108
# Bias:      -0.01191

# %%
# Compute residuals for 2-regime model
residuals_2r = y_test - pred_combined_2r

# Create "Residuals vs True SM | Hard Gated (Oracle - 2-Regime)" scatter plot
plt.figure(figsize=(7, 5))
plt.scatter(y_test, residuals_2r, s=8, alpha=0.5, color='#e76f51')
plt.axhline(0, color='black', linestyle='--', linewidth=1.2, alpha=0.8)
plt.xlabel("True Soil Moisture")
plt.ylabel("Residual (true - pred)")
plt.title("Residuals vs True SM | Hard Gated (Oracle - 2-Regime)")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()
