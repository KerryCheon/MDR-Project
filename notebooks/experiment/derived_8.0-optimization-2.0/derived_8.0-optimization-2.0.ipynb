# %% [markdown]
# # derived_8.0-optimization-2.0 — V21 LSTM + PCA + XGBoost with Accelerated SHAP
#
# Re-run of `derived_8.4-hybrid-lstm-1.5` on the **derived_8.0** dataset split (5 Washington stations) reusing the exact same feature sets (54-feature shared backbone, 58-feature V21 LSTM input, V0 router features, c1 additions). This experiment uses **V21 BiLSTM+Attn** (Jakob 38 + V9-unique features, seq_len=30, 1-seed training). After training, PCA is applied to all three frozen representations (160-dim ctx, 80-dim head_hidden, 80-dim pre-ReLU) at four compression levels (95% variance, 64 components, 32 components, 16 components) to evaluate how dimensionality reduction affects hybrid model performance.

# %%
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import yaml

# Handle both: run from notebooks/ dir and run from the experiment dir itself
_cwd = Path.cwd().resolve()
if (_cwd / "experiment" / "derived_8.0-optimization-2.0").is_dir():
    NOTEBOOK_DIR = _cwd / "experiment" / "derived_8.0-optimization-2.0"
else:
    NOTEBOOK_DIR = _cwd
PROJECT_ROOT = NOTEBOOK_DIR.parents[2]
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(NOTEBOOK_DIR))

from lstm.train import (
    train_v21_and_extract_all, ALL_FEATURES, SEQ_LEN,
)
from eval_hybrid.data import load_hybrid_experiment_data
from eval_hybrid.evaluator import HybridStrategyEvaluator
from eval_hybrid.shap_analysis import run_full_shap_analysis

with open(NOTEBOOK_DIR / "config.yaml") as f:
    config = yaml.safe_load(f)

ARTIFACTS_DIR = NOTEBOOK_DIR / "artifacts"
MODELS_DIR = NOTEBOOK_DIR / "models"
DATA_DIR = PROJECT_ROOT / config.get("data_dir", "data/splits/derived_8.0")
ARTIFACTS_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)

print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# ## Phase 1-3: V21 Training + Extraction + PCA
#
# Trains V21 BiLSTM+Attn (1 seed), extracts raw ctx/hh/hp vectors, computes PCA at 4 levels.

# %%
import json

has_raw = all((ARTIFACTS_DIR / f"{n}_{s}.npy").exists()
              for n in ("ctx", "head_hidden", "head_pre_relu")
              for s in ("train", "val", "test"))

from lstm.train import PCA_LEVELS as _PLEVELS
_pca_raw = ("ctx", "head_hidden", "head_pre_relu")
_pca_lvls = [lvl for lvl, _ in _PLEVELS]
has_pca = all((ARTIFACTS_DIR / f"{n}_{l}_{s}.npy").exists()
              for n in _pca_raw
              for l in _pca_lvls
              for s in ("train", "val", "test"))

if has_raw and has_pca:
    print("Found existing representations. Skipping V21 training.")
    with open(ARTIFACTS_DIR / "lstm_metrics.json") as f:
        lstm_metrics = json.load(f)
else:
    best_seed_info, pca_info, lstm_metrics = train_v21_and_extract_all(DATA_DIR, ARTIFACTS_DIR, MODELS_DIR)
    if best_seed_info:
        print(f"Best seed: {best_seed_info['seed']} (val_rmse={best_seed_info['val_rmse']:.5f})")
print(f"LSTM-only test R2 = {lstm_metrics['test']['r2']:.4f}")
# Out:
# Found existing representations. Skipping V21 training.
# LSTM-only test R2 = 0.7217

# %% [markdown]
# ## Phase 4-5: XGBoost Tabular Baselines + Hybrid Models
#
# Train 2 tabular baselines and 30 hybrid models (15 representation variants x 2 strategies).

# %%
from eval_hybrid.evaluator import HybridStrategyEvaluator
from run_eval import compute_c1_gain_additions, VARIANTS, _model_name, _candidate_id, _repr_suffix, REPR_LABELS, PCA_DISPLAY

c1_additions = compute_c1_gain_additions(config)
backbone_54 = config["shared_backbone_54"]

data_base = load_hybrid_experiment_data(PROJECT_ROOT, NOTEBOOK_DIR, config, repr_type="ctx", pca_suffix="")
eval_global = HybridStrategyEvaluator(data_base, config, "Global_Single", models_dir=MODELS_DIR)
eval_v0 = HybridStrategyEvaluator(data_base, config, "Clustering_V0_Full_k2", models_dir=MODELS_DIR)

results = {}
results["Global Single (54 Backbone)"] = eval_global.fit_and_evaluate(
    model_name="Global Single (54 Backbone)", candidate_id="Global_Single_54_Backbone",
    global_features=backbone_54,
)
results["Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10)"] = eval_v0.fit_and_evaluate(
    model_name="Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10)",
    candidate_id="Clustering_V0_k2_54_Backbone", global_features=backbone_54,
    cluster_additions={"0": [], "1": c1_additions},
)

for repr_type, pca_level in VARIANTS:
    suffix = _repr_suffix(pca_level)
    data_v = load_hybrid_experiment_data(PROJECT_ROOT, NOTEBOOK_DIR, config, repr_type=repr_type, pca_suffix=suffix)
    ev_g = HybridStrategyEvaluator(data_v, config, "Global_Single", models_dir=MODELS_DIR)
    ev_c = HybridStrategyEvaluator(data_v, config, "Clustering_V0_Full_k2", models_dir=MODELS_DIR)
    results[_model_name(repr_type, pca_level, "Global_Single")] = ev_g.fit_and_evaluate(
        model_name=_model_name(repr_type, pca_level, "Global_Single"),
        candidate_id=_candidate_id(repr_type, pca_level, "Global_Single"),
        global_features=data_v.hybrid_features,
    )
    results[_model_name(repr_type, pca_level, "Clustering_V0_Full_k2")] = ev_c.fit_and_evaluate(
        model_name=_model_name(repr_type, pca_level, "Clustering_V0_Full_k2"),
        candidate_id=_candidate_id(repr_type, pca_level, "Clustering_V0_Full_k2"),
        global_features=data_v.hybrid_features,
        cluster_additions={"0": [], "1": c1_additions},
    )

print(f"Trained {len(results)} XGBoost models.")
# Out:
# /scratch/group/p.cis250607.000/MDR-Project/notebooks/.venv/lib64/python3.12/site-packages/xgboost/core.py:751: UserWarning: [18:49:52] WARNING: /__w/xgboost/xgboost/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# Trained 32 XGBoost models.

# %% [markdown]
# ## Phase 6: SHAP Feature Importance Analysis
#
# Accelerated SHAP using XGBoost native pred_contribs (C++/CUDA tree traversal).

# %%
# Build per-model evaluator map for SHAP
eval_map = {}
for rtype, plevel in VARIANTS:
    suffix = _repr_suffix(plevel)
    dv = load_hybrid_experiment_data(PROJECT_ROOT, NOTEBOOK_DIR, config, repr_type=rtype, pca_suffix=suffix)
    ev_g = HybridStrategyEvaluator(dv, config, "Global_Single", models_dir=MODELS_DIR)
    ev_c = HybridStrategyEvaluator(dv, config, "Clustering_V0_Full_k2", models_dir=MODELS_DIR)
    eval_map[_model_name(rtype, plevel, "Global_Single")] = ev_g
    eval_map[_model_name(rtype, plevel, "Clustering_V0_Full_k2")] = ev_c

eval_map["Global Single (54 Backbone)"] = eval_global
eval_map["Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10)"] = eval_v0

shap_info = run_full_shap_analysis(eval_map, results, ARTIFACTS_DIR)
print(f"SHAP computed for {len(shap_info['shap_results'])} models.")
# Out:
# ===========================================================================
# Executing Accelerated SHAP Feature Importance Analysis
# ===========================================================================
# [SHAP] Computing SHAP values for: Global Single (54 Backbone)...
#   -> Done in 0.694s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10)...
#   -> Done in 0.642s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 160 CTX)...
#   -> Done in 0.795s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 160 CTX)...
#   -> Done in 0.704s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Head Hidden)...
#   -> Done in 0.732s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Head Hidden)...
#   -> Done in 0.660s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Pre-ReLU)...
#   -> Done in 0.792s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Pre-ReLU)...
#   -> Done in 0.690s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 160 CTX PCA-95%)...
#   -> Done in 0.743s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 160 CTX PCA-95%)...
#   -> Done in 0.667s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 160 CTX PCA-64)...
#   -> Done in 0.863s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 160 CTX PCA-64)...
#   -> Done in 0.742s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 160 CTX PCA-32)...
#   -> Done in 0.819s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 160 CTX PCA-32)...
#   -> Done in 0.705s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 160 CTX PCA-16)...
#   -> Done in 0.787s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 160 CTX PCA-16)...
#   -> Done in 0.702s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Head Hidden PCA-95%)...
#   -> Done in 0.751s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Head Hidden PCA-95%)...
#   -> Done in 0.667s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Head Hidden PCA-64)...
#   -> Done in 0.881s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Head Hidden PCA-64)...
#   -> Done in 0.747s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Head Hidden PCA-32)...
#   -> Done in 0.825s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Head Hidden PCA-32)...
#   -> Done in 0.715s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Head Hidden PCA-16)...
#   -> Done in 0.813s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Head Hidden PCA-16)...
#   -> Done in 0.709s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Pre-ReLU PCA-95%)...
#   -> Done in 0.720s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Pre-ReLU PCA-95%)...
#   -> Done in 0.656s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Pre-ReLU PCA-64)...
#   -> Done in 0.892s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Pre-ReLU PCA-64)...
#   -> Done in 0.758s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Pre-ReLU PCA-32)...
#   -> Done in 0.827s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Pre-ReLU PCA-32)...
#   -> Done in 0.735s (pred_contribs)
# [SHAP] Computing SHAP values for: Global Single (54 Backbone + 80 Pre-ReLU PCA-16)...
#   -> Done in 0.812s (pred_contribs)
# [SHAP] Computing SHAP values for: Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10 + 80 Pre-ReLU PCA-16)...
#   -> Done in 0.706s (pred_contribs)
# [SHAP] Saved summary table to /scratch/group/p.cis250607.000/MDR-Project/notebooks/experiment/derived_8.0-optimization-2.0/artifacts/shap_importance_summary.csv
# [SHAP] Saved visualization plot to /scratch/group/p.cis250607.000/MDR-Project/notebooks/experiment/derived_8.0-optimization-2.0/artifacts/shap_summary_plots.png
# SHAP computed for 32 models.

# %% [markdown]
# ## Results: Leaderboard

# %%
records = [r.as_record() for r in results.values()]
records.append({
    "model_name": "BiLSTM+Attn (LSTM-only, V21)",
    "pooled_r2": lstm_metrics["test"]["r2"],
    "pooled_rmse": lstm_metrics["test"]["rmse"],
    "pooled_ubrmse": lstm_metrics["test"]["ubrmse"],
    "pooled_bias": lstm_metrics["test"]["bias"],
    "pooled_mae": lstm_metrics["test"]["mae"],
    "pooled_pearson": float("nan"),
})
df = pd.DataFrame(records).sort_values("pooled_r2", ascending=False)
display_cols = ["model_name", "pooled_r2", "pooled_rmse", "pooled_mae", "pooled_pearson"]
display(df[display_cols].round(4))
# Out:
#                                            model_name  pooled_r2  pooled_rmse  \
# 21  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8341       0.0384
# 19  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8338       0.0384
# 29  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8336       0.0384
# 3   Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8336       0.0384
# 11  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8331       0.0385
# 9   Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8331       0.0385
# 15  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8330       0.0385
# 23  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8330       0.0385
# 13  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8325       0.0385
# 31  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8323       0.0386
# 7   Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8310       0.0387
# 27  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8307       0.0387
# 1    Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=10)     0.8289       0.0390
# 5   Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8287       0.0390
# 25  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8284       0.0390
# 17  Clustering_V0_Full_k2 (54 Backbone, c0=0, c1=1...     0.8282       0.0390
# 30   Global Single (54 Backbone + 80 Pre-ReLU PCA-16)     0.8201       0.0399
# 20  Global Single (54 Backbone + 80 Head Hidden PC...     0.8199       0.0400
# 18  Global Single (54 Backbone + 80 Head Hidden PC...     0.8194       0.0400
# 14       Global Single (54 Backbone + 160 CTX PCA-16)     0.8193       0.0400
# 26   Global Single (54 Backbone + 80 Pre-ReLU PCA-64)     0.8192       0.0400
# 8       Global Single (54 Backbone + 160 CTX PCA-95%)     0.8190       0.0401
# 28   Global Single (54 Backbone + 80 Pre-ReLU PCA-32)     0.8188       0.0401
# 2               Global Single (54 Backbone + 160 CTX)     0.8179       0.0402
# 22  Global Single (54 Backbone + 80 Head Hidden PC...     0.8179       0.0402
# 12       Global Single (54 Backbone + 160 CTX PCA-32)     0.8178       0.0402
# 4        Global Single (54 Backbone + 80 Head Hidden)     0.8162       0.0404
# 0                         Global Single (54 Backbone)     0.8156       0.0404
# 6           Global Single (54 Backbone + 80 Pre-ReLU)     0.8156       0.0404
# 16  Global Single (54 Backbone + 80 Head Hidden PC...     0.8151       0.0405
# 10       Global Single (54 Backbone + 160 CTX PCA-64)     0.8150       0.0405
# 24  Global Single (54 Backbone + 80 Pre-ReLU PCA-95%)     0.8146       0.0405
# 32                       BiLSTM+Attn (LSTM-only, V21)     0.7217       0.0497
#
#     pooled_mae  pooled_pearson
# 21      0.0276          0.9165
# 19      0.0276          0.9161
# 29      0.0274          0.9163
# 3       0.0274          0.9160
# 11      0.0275          0.9155
# 9       0.0273          0.9155
# 15      0.0274          0.9155
# 23      0.0276          0.9161
# 13      0.0275          0.9154
# 31      0.0276          0.9158
# 7       0.0275          0.9152
# 27      0.0279          0.9151
# 1       0.0278          0.9140
# 5       0.0278          0.9136
# 25      0.0278          0.9137
# 17      0.0278          0.9137
# 30      0.0291          0.9096
# 20      0.0291          0.9093
# 18      0.0292          0.9090
# 14      0.0290          0.9088
# 26      0.0292          0.9094
# 8       0.0291          0.9089
# 28      0.0292          0.9087
# 2       0.0291          0.9080
# 22      0.0293          0.9081
# 12      0.0292          0.9081
# 4       0.0293          0.9070
# 0       0.0295          0.9072
# 6       0.0292          0.9069
# 16      0.0294          0.9069
# 10      0.0294          0.9066
# 24      0.0295          0.9066
# 32      0.0372             NaN

# %% [markdown]
# ## Save Artifacts & Generate README

# %%
df.to_csv(ARTIFACTS_DIR / "summary_records.csv", index=False)
with open(ARTIFACTS_DIR / "metrics.json", "w") as f:
    json.dump({k: r.as_record() for k, r in results.items()}, f, indent=2)

from run_eval import generate_readme
df_regime = pd.DataFrame()
generate_readme(df, df_regime, shap_info)
print("README generated.")
# Out:
# [Generated] /scratch/group/p.cis250607.000/MDR-Project/notebooks/experiment/derived_8.0-optimization-2.0/README.md
# README generated.
